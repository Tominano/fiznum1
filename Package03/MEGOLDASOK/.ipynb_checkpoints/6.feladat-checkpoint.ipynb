# %% [markdown]
# # ☠ 6. feladat
# ### 3D-s ábrák - II.
#
# Ábrázoljuk az alábbi paraméteresen megadott felületet:
#
# \begin{align}
# x&= (2 + \cos (\theta))\cos{(\varphi)}, \\
# y&= (2 + \cos (\theta))\sin{(\varphi)}, \\
# z&=  \sin( \theta).
# \end{align}
#
# - A felület paraméterei az $\theta,\varphi\in[0,2\pi]$ intervallumban fussanak!
# - Az ábra színskálája a "viridis" legyen!
# - Minden ábrádnak legyen tengelyfelirata és címe!
#
# A `matplotlib` vagy a `plotly` könyvtárak bármelyikét használhatod!

# %%
# %pylab inline     
from mpl_toolkits.mplot3d import * #3D-s ábrák alcsomagja
from ipywidgets import *  #interaktivitáshoz szükséges függvények
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
theta,phi=meshgrid(linspace(0,2*pi,25),linspace(0,2*pi,25)) # a thetára és phire legyártom a pontokat
x=(2 + 1*cos(theta))*cos(phi)  
y=(2 + 1*cos(theta))*sin(phi)    #megadom a három változós függvényt
z=1*sin(theta)

# %%
ax = subplot(111, projection='3d')  #megmondom neki hogy 3d-ban ábrázoljon
ax.plot_surface(x, y, z,rstride=1,cstride=1,cmap='viridis') #majd ábrázolom a felületet a megadott beálltásoknak megfelelően
ax.set_xlabel('x tengely',labelpad=3)
ax.set_ylabel('y tengely',labelpad=3)  # tengelyfeliratokat helyezek el
ax.set_zlabel('z tengely',labelpad=3)
