# %% [markdown]
# # 1. feladat
#
# ### Ábrázolás - R
#
# - Olvasd be a `../data/cica.txt` fájlt!
# - Számold ki a második oszlop adatainak átlagát és szórását!
# - Ábrázold a harmadik és ötödik oszlop adatait!
# - Az adatokat zöld telt karikákkal jelenítsd meg!

# %%
dat <- read.csv(file = "../data/cica.txt")  # beolvasom az adatokat

# %%
str(dat) # megnézem a file minden tulajdonságát, hogy megtudjam hogy a beolvasáskor alakítsam-e az adathalmazt vagy se...
# Out:
# 'data.frame':	20 obs. of  6 variables:
#  $ Cica_neve      : Factor w/ 20 levels "Aphrodité","Bolhazsák",..: 13 11 14 1 3 19 15 16 9 7 ...
#  $ Súly           : num  8.29 12.48 8.51 12.13 7.65 ...
#  $ Szépség        : int  19 68 34 67 31 54 37 97 56 18 ...
#  $ Születési_dátum: Factor w/ 12 levels "1905-06-24","1905-06-25",..: 12 9 3 5 6 4 9 9 5 2 ...
#  $ Ügyesség       : int  170 406 199 372 180 254 194 477 356 143 ...
#  $ Nem            : Factor w/ 2 levels "Hím","Nőstény": 2 1 1 2 2 1 1 2 1 1 ...

# %%
summary(dat) #összegzem a fontos változókat az adathalmazról, ebből ki tudom olvasni az átlagot is
# Out:
#      Cica_neve       Súly           Szépség        Születési_dátum
#  Aphrodité: 1   Min.   : 4.530   Min.   :18.00   1905-07-04:3
#  Bolhazsák: 1   1st Qu.: 8.365   1st Qu.:36.25   1905-06-27:2
#  Bolyhos  : 1   Median :10.220   Median :59.50   1905-06-29:2
#  Cica     : 1   Mean   : 9.906   Mean   :58.95   1905-06-30:2
#  Cuki     : 1   3rd Qu.:12.160   3rd Qu.:78.50   1905-07-01:2
#  Fáraó    : 1   Max.   :13.310   Max.   :97.00   1905-07-06:2
#  (Other)  :14                                    (Other)   :7
#     Ügyesség          Nem
#  Min.   :143.0   Hím    :11
#  1st Qu.:197.8   Nőstény: 9
#  Median :362.0
#  Mean   :331.2
#  3rd Qu.:421.2
#  Max.   :526.0

# %% [markdown]
# ##### A Summary-ból kiolvasom a második oszlop átlagát
# ### A második oszlop átlaga: 9,906

# %%
sd(dat$Súly) # így ia kiszámolhatom a szórást
# Out:
# [1] 2.477771

# %%
x <- var(dat$Súly)
z <- x^(1/2)
print(z)  # igy is kiszámítjuk a szórását
# Out:
# [1] 2.477771

# %%
plot(dat$Szépség,dat$Ügyesség, xlab="Szépség", ylab="Ügyesség", main="Minta", col="green", pch=16, type="p") 
# majd plotolom és beállítom a kért paramétereket
# Out:
# Plot with title “Minta”
