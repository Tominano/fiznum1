# %% [markdown]
# ## 03 - Korreláció
#
# Vessük össze az előző feladatban beolvasott két adattáblát.
#
# - Fésüljük össze a két adattáblát az éveket tartalmazó oszlop értékei alapján úgy, hogy csak azokhoz az évekhez tartozó sorok maradjanak meg, melyekhez mindkét táblázatban szerepel adat.
#
# - Az így kapott összefésült táblázatban nézzük meg, hogy a korábban kiszámolt éves átlaghőmérséklet mennyire korrelál az átlagos $CO_2$-koncentrációval. (Számoljunk korrelációt!) Ábrázoljuk az éves átlaghőmérsékletet a $CO_2$-koncentráció függvényében.

# %%
# %pylab inline
import pandas as pd # szokásos importok
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dat=pd.read_csv("../data/T_adat.csv",header=1,na_values="***") # A file beolvasása
co2adat=pd.read_csv("../data/co2_adat.txt", header=None, delim_whitespace=True, 
                comment='#',names=('Year','ja','ddate','average','interpolated','trend','days'))

# %%
df=dat.merge(co2adat,how='inner',
             left_on='Year',          
             right_on='Year')
df.head()
# Out:
#    Year   Jan   Feb  Mar   Apr   May   Jun   Jul   Aug   Sep  ...    DJF  \
# 0  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03  ...   0.27
# 1  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03  ...   0.27
# 2  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03  ...   0.27
# 3  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03  ...   0.27
# 4  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03  ...   0.27
#
#     MAM   JJA   SON  ja     ddate  average  interpolated   trend  days
# 0  0.06 -0.02  0.01   3  1958.208   315.71        315.71  314.62    -1
# 1  0.06 -0.02  0.01   4  1958.292   317.45        317.45  315.29    -1
# 2  0.06 -0.02  0.01   5  1958.375   317.50        317.50  314.71    -1
# 3  0.06 -0.02  0.01   6  1958.458   -99.99        317.10  314.85    -1
# 4  0.06 -0.02  0.01   7  1958.542   315.86        315.86  314.98    -1
#
# [5 rows x 25 columns]

# %%
subdf=tadat[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep','Oct', 'Nov', 'Dec', ]]
df['avr']=subdf.mean(axis=1)
df.head()  #átlegokat hozzáadom
# Out:
#    Year   Jan   Feb  Mar   Apr   May   Jun   Jul   Aug   Sep    ...      MAM  \
# 0  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03    ...     0.06
# 1  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03    ...     0.06
# 2  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03    ...     0.06
# 3  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03    ...     0.06
# 4  1958  0.39  0.24  0.1  0.01  0.08 -0.05  0.06 -0.06 -0.03    ...     0.06
#
#     JJA   SON  ja     ddate  average  interpolated   trend  days       avr
# 0 -0.02  0.01   3  1958.208   315.71        315.71  314.62    -1 -0.195000
# 1 -0.02  0.01   4  1958.292   317.45        317.45  315.29    -1 -0.104167
# 2 -0.02  0.01   5  1958.375   317.50        317.50  314.71    -1 -0.090000
# 3 -0.02  0.01   6  1958.458   -99.99        317.10  314.85    -1 -0.195000
# 4 -0.02  0.01   7  1958.542   315.86        315.86  314.98    -1 -0.266667
#
# [5 rows x 26 columns]

# %%
import seaborn as sns
x,y='interpolated','avr'   #kiiratom
sns.jointplot(x=x, y=y, data=df,kind="scatter", color="k")
