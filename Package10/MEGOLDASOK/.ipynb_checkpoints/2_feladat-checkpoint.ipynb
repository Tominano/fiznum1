# %% [markdown]
# # 2. feladat
#
# ### Véletlen feladat - R
#
# - Készíts egy véletlen számokból álló 500 elemű listát, melynek elemei 1 és 501 között vannak!
# - Készíts 1-től 501-ig egy számsort is, melynek keverd össze az elemeit!
# - Hasonlítsd össze a véletlen listát az összekevert listával [Kolmogorov–Szmirnov-próba](https://hu.wikipedia.org/wiki/Kolmogorov%E2%80%93Szmirnov-pr%C3%B3ba) segítségével! Az eredményt **diszkutáljuk** szövegesen, melyben kitérünk a [szignifikancia](http://kaufmann.web.elte.hu/estat/Student_t.pdf) szintekre is.
# - Vizsgájuk meg [Shapiro–Wilk test](https://en.wikipedia.org/wiki/Shapiro%E2%80%93Wilk_test) segítségével, hogy a két lista normális eloszást követ-e?

# %%
random<-runif(n = 500, min = 1, max = 501) # runif függvénnyel normál eloszlású véletlen számokat gerenálok és ezt belepakolom a randomba

# %%
x<-seq(1,501,1) # belepakolok az x-be egy 1-től 500 ig tartó 1 differenciállal növő számhalmazt
y<-sample(x=500) # majd x-et összekeverem a sample függvénnyel és bepakolomay-ba

# %%
ks.test(random,y) # lefuttatom a beépített Kolmogorov–Szmirnov-próbát
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  random and y
# D = 0.028, p-value = 0.9895
# alternative hypothesis: two-sided

# %% [markdown]
# #### A p-value megmutatja hogy 98.95%-ra megyeggyezik a két minta.

# %%
shapiro.test(dnorm(y)) #shapiro tesztel megnézem hogy normál eloszlásóak-e
# Out:
# 	Shapiro-Wilk normality test
#
# data:  dnorm(y)
# W = 0.029203, p-value < 2.2e-16

# %%
shapiro.test(dnorm(random))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  dnorm(random)
# W = 0.034207, p-value < 2.2e-16

# %%
shapiro.test(random)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  random
# W = 0.95547, p-value = 3.847e-11

# %%
shapiro.test(y)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  y
# W = 0.95472, p-value = 2.946e-11
