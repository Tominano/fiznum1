# %% [markdown]
# ## 4. feladat
#
# #### Függvények - II.
#
# Írj egy függvényt, ami a $$ ax^2+bx+c=0 $$ másodfokú egyenlet (valós és komplex) gyökeit határozza meg. Csak akkor kapjunk eredményként komplex számot, ha a diszkrimináns negatív!
#
# Példaként add meg a következő négy egyenlet megoldását:
# 1. $x^2=100$
# 2. $3x^2-25x=10$
# 3. $-4x^2+4x=1$
# 4. $25x^2+16x=-100$

# %%
import math, cmath #meghívom a műveletek elvégzéséhez szükséges csomagokat

def masodfoku(a,b,c):
    print('Az egyenlet a: {0}x**2 + {1}x + {2}'.format(a,b,c))

while a==0:  # ha az érték nulla akkor nem lesz másod fokú az egyenlet
    print('Ez nem lesz másodfokú egyenlet; nem oldom meg.')
    a= input('Kérem a másodfokú egyenlet főegyütthatóját: ')
    a= float(a)

d= b**2 - 4 * a * c  # meghatározom a diszkrimináns értékét hogy könnyebb legyen gyök alá rakni
print('A diszkrimináns értéke', d) #majd kiírom az értékét

if d>0:     #végrehajtom a diszkrimináns vizsgálatot
    print('Van valós megoldás.') #kiiratom a tulajdonságát
    x1= (-b-math.sqrt(d))/(2*a)  #ez a diszkrimináns megoldása
    x2= (-b+math.sqrt(d))/(2*a)  # ez a másik megoldás
    print('Az egyik megoldás', x1)
    print('A másik megoldás', x2)  # majd kiiratom
elif d==0:  # ha épp egyenlő nullával akor csak 1 megoldása van
    print('Egy megoldása van')
    x= -b/(2*a)
    print('A megoldás', x) #majd kiiratom
elif:      #ha nem nagyob mint nulla és nem egyenlő nullával akkor komplex megoldása van
    print('Nincs valós megoldás.')
    x1= (-b-cmath.sqrt(d))/(2*a)
    x2= (-b+cmath.sqrt(d))/(2*a)
    print('Az egyik megoldás', x1)
    print('A másik megoldás', x2) #majd kiiratom

    
masodfoku(1,0,-100)

masodfoku(3,-25,-10)

masodfoku(-4,4,-1)

masodfoku(25,16,100)

# %%
import math
import cmath

# Létrehozom a függvényt, amiben az összes kimenetel lehetőségét lekezelem
def masodfoku(a,b,c):
    print('Az egyenlet a: {0}x**2 + {1}x + {2}'.format(a,b,c))

    # Ebben a blokkban a diszkrimináns 3 lehetséges értékét ifeltem le
    diszkriminans = b**2 - 4 * a * c
    if diszkriminans > 0:
        gyok1 = (-b + math.sqrt(diszkriminans))/ (2 * a)
        gyok2 = (-b - math.sqrt(diszkriminans))/ (2 * a)
        print('Két gyöke van:')
        return gyok1, gyok2
    elif diszkriminans == 0:
        gyok1 = float(-b + math.sqrt(diszkriminans))/ (2 * a)
        print('Két valós gyöke egyenlő és ez a:')
        return gyok1
    elif diszkriminans < 0:
        gyok1 = (-b + cmath.sqrt(diszkriminans))/ (2 * a)
        gyok2 = (-b - cmath.sqrt(diszkriminans))/ (2 * a)
        print('Két komplex megoldása van:')
        return gyok1, gyok2

masodfoku(1,0,-100)

masodfoku(3,-25,-10)

masodfoku(-4,4,-1)

masodfoku(25,16,100)
