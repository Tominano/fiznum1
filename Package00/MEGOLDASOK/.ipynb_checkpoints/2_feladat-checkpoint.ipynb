# %% [markdown]
# ## 02-Barometrikus magasságformula
# Írd le a barometrikus magasságformulát! Ha esetleg nem emlékeznél rá, akkor [itt](http://www.google.com) meglelheted a megoldást!

# %% [markdown]
# ## **Az egyenletet az interneten az alábbi formulában találtam meg:**
#
# $$p(h)=p_0\cdot \mathrm{e}^{- \left(\rho_0\cdot\frac{gh}{p_o} \right)}$$
#
# [A képlet forrása a linkre kattintva megtekinthető](http://slideplayer.hu/slide/2132051/)
