# %% [markdown]
# # 2. feladat
#
# #### Karakterkeresés
#
# Írjunk meg a saját grep függvényünket!
#
# Kérjen egy fájlnevet, illetve egy karakterláncot, majd írja ki azokat a sorokat, amikben a karakterlánc megtalálható.
# A grep parancshoz hasonlóan a függvény ne használjon sok memóriát gigantikus fájlok esetén sem!
#
# **A feladat megoldása során a `numpy` csomag `loadtxt()` parancsa nem használható!**

# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
word = 'nyárfa'  # ezt a szót keressük
file = '../data/szeptemer_vegen.txt' #ebben a file-ban
#nyarfa = []
def grep(fn, s):  # definiálom a függvényt
    with open(fn,'r') as f:  # olvasom
        for line in f.readlines(): #olvasom a sorokat
            if word in line:      #keresem a szó
                #nyarfa.append(line)
                print (line) # igy sem írja ki
#grep(file, word)
#nyarfa

# %% [markdown]
# Az elős 10 alkalmmal kiírta a mondatot, majd a kommentek után már nem....
# kernel restart után és logout után sem akart kiírni a mondatot...
