# %% [markdown]
# ##  1. Feladat
# #### láthatóság
#
# Írjuk meg  `a_fuggveny_ami_azt_mondja_ping()` nevű függvényt, ami a meghívása esetén beleírja a végrehajtás pontos idejét az `utolso_ping` nevű globális változóba.
#
# - `a_fuggveny_ami_azt_mondja_ping()` függvénynek nem lehet argumentuma,
# - a pontos időhöz használjuk a datetime modul datetime.now() függvényét,
# - az `utolso_ping` típusa legyen karakterlánc.

# %%
utolso_ping='a'  #definiálom az utolsó_ping et string-ként amibe beírom majd a változásokat
print(utolso_ping) #ki írom és látszik a stringem változatlanul
def a_fuggveny_ami_azt_mondja_ping():  #definiálom a függvényt amire hivatkozok majd
    global utolso_ping #A global utasítással a függvényen kívülről behívom az utolsó_pinget globális változónak
    import datetime as d #meghívom a datetime modult d ként, hogy az időt le tudjam kérni
    pontos_ido=d.datetime.now() #definiálom a pontos_időt d.datetime.now() segítségével
    utolso_ping=pontos_ido #az utolsó_pinget a pontos_idő-re fog kiutalni
    print(utolso_ping)   #ki iratom az utolsó_pinget a definiált függvényem alapján
a_fuggveny_ami_azt_mondja_ping()
# Out:
# a
# 2017-03-05 12:44:32.619494
