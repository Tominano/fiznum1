# %% [markdown]
# # 2. feladat
# ### Egyszerű kétváltozós függvény - I.
#
# - Ábrázold `pcolor` használatával az $$ f(x,y)=e^{-(x-1)^2-(y+1.5)^2}+\cos(x^3-3y^2) $$ függvényt az $x\in[-3,3],\  y\in[-3,3]$ tartományban! A színskála 'magma' legyen és készíts színmagyarázatot (colorbar-t)!
#
# - Jelöld meg ugyanezen a képen azokat a pontokat az $(x-y)$ síkon, melyekre a fent definiált $f(x,y)$ függvény a $-0.25$ és $0.5$ értékeket veszi fel! Használd a `contour` függvényt! Legyen a kontúrvonalakra felírva a szintjük is!
#
# - Az ábrádnak legyen címe, és tengelyfeliratai!

# %%
# %pylab inline #meghívom a szükséges csomagot az ábrázoláshoz és a számításokhoz
figsize(8,6) #méretezem 
x,y = meshgrid(linspace(-3,3,50),linspace(-3,3,50)) #megadom hogy mettől meddig ábrázoljon
z = exp(-(x-1)**2-(y+1.5)**2)+cos(x**3-3*(y**2)) #megadom a függvényt amit ábrázolni kell
pcolor(x,y,z,cmap='magma') #ábrázolom és szín típust adok meg
title('Ábrázolás') #címet adok az ábrának
xlabel('X') # a tengelyeket is elnevezem
ylabel('Y')
colorbar() #sínskálát is megadok
cs=contour(x,y,z,levels=[-0.25,0.5],colors='white') # fehér kontúrokat adok meg -0,25 és0,5 határokon
clabel(cs)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <a list of 24 text.Text objects>
