# %% [markdown]
# # 4. feladat
#
# #### Fits fájlok - I.
#
# Adott a **data/hf.fits** állomány. A tanult módon olvasd be a pythonba, majd végezd el a következő feladatokat:
#
# - Listázd ki a fájlban levő HDU-kat.
# - Válaszd ki a 'BAT_IMAGE_2' nevő blokkot
# - A kiválasztott blokk fejlécéből olvasd ki a következő változók értékét:
# "E_MIN", "E_MAX", "EXPOSURE", "TSTART", TSTOP", "DATE-OBS"
# - Add meg, hogy a kiválaszott adattömb, hanyadik energiabinnek felel meg, az "EBOUNDS" hdu adatai alapján.
# - Ábrázold (`imshow`) a kiválaszott adatsort égi kordinátarendszerben a következő paraméterekkel:
# `cmap="jet", origin='lower', vmin=-0.001, vmax=0.001`

# %%
#from astropy.io import fits
import astropy.io.fits as fits
#from astropy import wcs as wcs
import astropy.wcs as wcs
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
file1 = open('../data/hf.fits')
hdu=fits.open('../data/hf.fits')
hdu.info()
len(hdu[1].header)
# Out:
# Filename: ../data/hf.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  BAT_IMAGE_1  PrimaryHDU     254   (1760, 954)   float32
#   1  BAT_IMAGE_2  ImageHDU       253   (1760, 954)   float32
#   2  EBOUNDS     BinTableHDU    155   1R x 3C   [I, E, E]
#   3  STDGTI      BinTableHDU     72   1R x 2C   [D, D]
# 253

# %%
hdu[1].header[:] # Ebből ki tudom olvasni a kért adatokat
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 1760 / length of data axis 1
# NAXIS2  =                  954 / length of data axis 2
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# EXTNAME = 'BAT_IMAGE_2'        / Name of extension
# HDUCLASS= 'OGIP    '           / Conforms to OGIP/GSFC standards
# HDUCLAS1= 'IMAGE   '           / Contains image data
# HDUCLAS2= 'NET     '           / Contains net flux map
# TIMESYS = 'TT      '           / Time system
# MJDREFI =               51910. / Reference MJD Integer part
# MJDREFF =         7.4287037E-4 / Reference MJD fractional
# TIMEREF = 'LOCAL   '           / Time reference (barycenter/local)
# TASSIGN = 'SATELLITE'          / Time assigned by clock
# TIMEUNIT= 's       '           / Time unit
# TIERRELA=               1.0E-8 / [s/s] relative errors expressed as rate
# TIERABSO=                  1.0 / [s] timing  precision  in seconds
# TSTART  =           221640605. / start time of image
# TSTOP   =           221640783. / stop time of image
# DATE-OBS= '2008-01-10T06:45:04'
# DATE-END= '2008-01-10T06:53:02'
# CLOCKAPP=                    F / default
# TELAPSE =                 178. / elapsed time of image (= TSTOP-TSTART)
# ONTIME  =                 178. / on-time of image
# LIVETIME=                 178. / [s] ONTIME multiplied by DEADC
# EXPOSURE=                 178. / exposure of image
# DEADC   =                   1. / Dead time correction factor
# TIMEPIXR=                   0. / Time bin alignment
# TELESCOP= 'SWIFT   '           /  Telescope (mission) name
# INSTRUME= 'BAT     '           /  Instrument name
# DATAMODE= 'DPI_1   '           / Instrument data mode
# OBS_ID  = '00035941003'        / Observation ID
# TARG_ID =                35941 / Target ID
# SEG_NUM =                    3 / Segment number
# EQUINOX = 2000.                / default
# RADECSYS= 'FK5'                / default
# OBS_MODE= 'POINTING'           / default
# ORIGIN  = 'GSFC'               / Source of FITS file
# CREATOR = 'batfftimage 1.20'   / Program that created this FITS file
# TLM2FITS= 'V7.13'               / Telemetry converter version number
# DATE    = '2015-09-11T16:16:15' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# GAINAPP =                    T / Gain correction has been applied
# GAINMETH= 'FLIGHT'             / Flight gain/offset correction was applied
# LDPEBINS=                   80 / LDP Energy Bin count
# LDPTYPE =                    0 / LDP Type Code
# LDPGAIN =                 859. / LDP Gain Index
# LDPOFFST=                2563. / LDP Offset Index
# HISTORY No single packet ApIDs contributed.
# HISTORY LDP(567,63846) File: swift_ldp_008c6503_0a05_567_63846.ccsds
# HISTORY     Product(63846) BAT Pages(909) Found Pages(909)
# HISTORY     Valid Pages(909) Simulated Pages (0) Missing Pages(0)
# HISTORY LDP(567,63850) File: swift_ldp_008c6503_0a05_567_63850.ccsds
# HISTORY     Product(63850) BAT Pages(866) Found Pages(866)
# HISTORY     Valid Pages(866) Simulated Pages (0) Missing Pages(0)
# PROCVER = '3.16.09 '           / Processing script version
# SOFTVER = 'Hea_21Dec2012_V6.13_Swift_Rel4.0(Bld29)_14Dec2012_SDCpatch_15'
# CALDBVER= 'b20090130_u20111031_x20140610_m20150707' / CALDB index versions used
# SEQPNUM =                   11 / Number of times the dataset processed
# OBJECT  = 'BZQJ0618+4620'      / Object name
# RA_OBJ  =            94.534167 / [deg] R.A. Object
# DEC_OBJ =            46.338056 / [deg] Dec Object
# RA_PNT  =     94.5183593051574 / [deg] RA pointing
# DEC_PNT =     46.3426889034363 / [deg] Dec pointing
# PA_PNT  =     345.221544161532 / [deg] Position angle (roll)
# ATTFLAG = '110     '           / Attitude file: 100=sat, x10=pat, xx1=uat
# UTCFINIT=    -2.49164000000000 / [s] UTCF at TSTART
# BACKAPP =                    F / Was background correction applied?
# FLUXMETH= 'WEIGHTED'           / Flux extraction method
# HISTORY
# HISTORY START PARAMETER list for batbinevt_1.48 at 2017-02-06T15:40:49
# HISTORY
# HISTORY P1 infile = sw00035941003bsvpbo0a03g035b.dph.gz
# HISTORY P2 outfile = outfile_all.dph
# HISTORY P3 outtype = DPH
# HISTORY P4 timedel = 0
# HISTORY P5 timebinalg = infile
# HISTORY P6 energybins = 14-194.9
# HISTORY P7 gtifile = NONE
# HISTORY P8 ecol = ENERGY
# HISTORY P9 weighted = INDEF
# HISTORY P10 outunits = INDEF
# HISTORY P11 timepixr = -1.0
# HISTORY P12 maskwt = NONE
# HISTORY P13 tstart = INDEF
# HISTORY P14 tstop = INDEF
# HISTORY P15 snrthresh = 6.0
# HISTORY P16 detmask = NONE
# HISTORY P17 tcol = TIME
# HISTORY P18 countscol = DPH_COUNTS
# HISTORY P19 xcol = DETX
# HISTORY P20 ycol = DETY
# HISTORY P21 maskwtcol = MASK_WEIGHT
# HISTORY P22 ebinquant = 0.1
# HISTORY P23 delzeroes = NO
# HISTORY P24 minfracexp = 0.1
# HISTORY P25 min_dph_frac_overlap = .999
# HISTORY P26 min_dph_time_overlap = 0
# HISTORY P27 max_dph_time_nonoverlap = 0.5
# HISTORY P28 buffersize = 16384
# HISTORY P29 clobber = YES
# HISTORY P30 chatter = 2
# HISTORY P31 history = YES
# HISTORY P32 mode = ql
# HISTORY END PARAMETER list for batbinevt_1.48
# HISTORY
# TOTCOUNT=              1248684 / Total counts per time sample
# E_MIN   =                  14. / [keV] Lower energy bin edge
# E_MAX   =                194.9 / [keV] Upper energy bin edge
# DPHLEVEL=                    1 / DPH level number
# HISTORY
# HISTORY START PARAMETER list for batbinevt_1.48 at 2017-02-06T15:40:50
# HISTORY
# HISTORY P1 infile = outfile_all.dph
# HISTORY P2 outfile = total_alll.dpi
# HISTORY P3 outtype = DPI
# HISTORY P4 timedel = 0.0
# HISTORY P5 timebinalg = i
# HISTORY P6 energybins = 14-194.9
# HISTORY P7 gtifile = NONE
# HISTORY P8 ecol = ENERGY
# HISTORY P9 weighted = NO
# HISTORY P10 outunits = RATE
# HISTORY P11 timepixr = -1.0
# HISTORY P12 maskwt = NONE
# HISTORY P13 tstart = INDEF
# HISTORY P14 tstop = INDEF
# HISTORY P15 snrthresh = 6.0
# HISTORY P16 detmask = master_all.detmask
# HISTORY P17 tcol = TIME
# HISTORY P18 countscol = DPH_COUNTS
# HISTORY P19 xcol = DETX
# HISTORY P20 ycol = DETY
# HISTORY P21 maskwtcol = MASK_WEIGHT
# HISTORY P22 ebinquant = 0.1
# HISTORY P23 delzeroes = NO
# HISTORY P24 minfracexp = 0.1
# HISTORY P25 min_dph_frac_overlap = .999
# HISTORY P26 min_dph_time_overlap = 0
# HISTORY P27 max_dph_time_nonoverlap = 0.5
# HISTORY P28 buffersize = 16384
# HISTORY P29 clobber = YES
# HISTORY P30 chatter = 2
# HISTORY P31 history = YES
# HISTORY P32 mode = ql
# HISTORY END PARAMETER list for batbinevt_1.48
# HISTORY
# BUNIT   = 'count/s '           / physical unit of image
# OVERSMPX=                    2 / Image oversampling in IMX direction
# OVERSMPY=                    2 / Image oversampling in IMY direction
# COMMENT ---------------------------------- Default Coordinates
# CTYPE1  = 'RA---TAN'           / Name of coordinate
# CUNIT1  = 'deg     '           / Units of coordinate axis
# CRPIX1  =     879.643202380952 / Reference pixel position
# CDELT1  =   -0.120381150504118 / Pixel spacing in physical units
# CRVAL1  =     94.5306932792557 / Coordinate value at reference pixel position
# CTYPE2  = 'DEC--TAN'           / Name of coordinate
# CUNIT2  = 'deg     '           / Units of coordinate axis
# CRPIX2  =      476.64789047619 / Reference pixel position
# CDELT2  =    0.120381150504118 / Pixel spacing in physical units
# CRVAL2  =     46.3578478432786 / Coordinate value at reference pixel position
# CROTA2  =     16.9873790415234 / [deg] WCS Roll of coordinates w.r.t. sky
# COMMENT ---------------------------------- Tangent Plane Coordinates
# WCSNAMET= 'TANGENT_PLANE'      / Coordinate system name
# WCSTY1T = 'TANGENT '           / Coordinate system axis
# CTYPE1T = 'IMX     '           / Name of coordinate
# CRPIX1T =     879.643202380952 / Reference pixel position
# CDELT1T = -0.00210105052526263 / Pixel spacing in physical units
# CRVAL1T =                   0. / Coordinate value at reference pixel position
# WCSTY2T = 'TANGENT '           / Coordinate system axis
# CTYPE2T = 'IMY     '           / Name of coordinate
# CRPIX2T =      476.64789047619 / Reference pixel position
# CDELT2T =  0.00210105052526263 / Pixel spacing in physical units
# CRVAL2T =                   0. / Coordinate value at reference pixel position
# COMMENT ---------------------------------- BAT Mask Orientation
# MASKBATX=                   0. / [cm] Center of mask tile plane in BAT_X
# MASKBATY=                   0. / [cm] Center of mask tile plane in BAT_Y
# MASKBATZ=                100.3 / [cm] Top of mask tile plane in BAT_Z
# MASKOFFX=               -0.145 / [cm] Offset of mask in BAT_X
# MASKOFFY=                0.114 / [cm] Offset of mask in BAT_Y
# MASKOFFZ=                 0.05 / [cm] Offset of mask in BAT_Z
# MASKX0  =              -124.25 / [cm] Position of mask corner in BAT_X
# MASKY0  =               -63.25 / [cm] Position of mask corner in BAT_Y
# MASKPSI0=                   0. / [deg] Mask Euler rotation about X-axis
# MASKPSI1=                   0. / [deg] Mask Euler rotation about Y-axis
# MASKPSI2=                   0. / [deg] Mask Euler rotation about Z-axis
# MASKCELX=                  0.5 / [cm] Size of mask cell in BAT_X
# MASKCELY=                  0.5 / [cm] Size of mask cell in BAT_Y
# MASKCELZ=                  0.1 / [cm] Size of mask cell in BAT_Z
# COMMENT ---------------------------------- BAT Detector Orientation
# DETBATX =                   0. / [cm] Center of detector plane in BAT_X
# DETBATY =                   0. / [cm] Center of detector plane in BAT_Y
# DETBATZ =                 0.35 / [cm] Top of detector plane in BAT_Z
# DETOFFX =                   0. / [cm] Offset of detector plane in BAT_X
# DETOFFY =                   0. / [cm] Offset of detector plane in BAT_Y
# DETOFFZ =                   0. / [cm] Offset of detector plane in BAT_Z
# DETCELX =                 0.42 / [cm] Size of detector pitch cell in BAT_X
# DETCELY =                 0.42 / [cm] Size of detector pitch cell in BAT_Y
# DETCELZ =                  0.2 / [cm] Size of detector pitch cell in BAT_Z
# DETSIZEX=                  0.4 / [cm] Size of detector in BAT_X
# DETSIZEY=                  0.4 / [cm] Size of detector in BAT_Y
# DETSIZEZ=                  0.2 / [cm] Size of detector in BAT_Z
# IMATYPE = 'INTENSITY'          / Contains net flux map
# ACOLAPP =                    T / Was autocollimation correction applied?
# PCODEAPP=                    T / Partial coding correction applied?
# FFAPP   =                    T / Projection correction applied?
# NBATDETS=                24094 / Number of enabled detectors
# NGOODPIX=                24094 / Number of enabled detectors
# NGPIXAPP=                    T / Normalized by number of detectors?
# BDISTAPP=                    F / BAT image corrected for distortions?
# MSKWTAPP=                    T / Correction for mask weight technique applied?
# MSKWTSQF=    0.267802196237411 / Half-variance of mask weights
# APERTURE= 'swbaperflux20041120v001.fits' / BAT aperture file name
# BTELDEF = 'swb20070911v001.teldef' / BAT teldef file name
# HISTORY
# HISTORY START PARAMETER list for batfftimage_1.20 at 2017-02-06T15:40:52
# HISTORY
# HISTORY P1 infile = total_alll.dpi
# HISTORY P2 outfile = s00035941003_all_2.img.fits
# HISTORY P3 attitude = ../../auxil/sw00035941003sat.fits.gz
# HISTORY P4 aperture = CALDB:FLUX
# HISTORY P5 bkgfile = NONE
# HISTORY P6 detmask = master_all.detmask
# HISTORY P7 bkgvarmap = NONE
# HISTORY P8 signifmap = NONE
# HISTORY P9 bkgvartype = STDDEV
# HISTORY P10 maskoffx = +0.0
# HISTORY P11 maskoffy = +0.00
# HISTORY P12 maskoffz = +0.00
# HISTORY P13 bat_z = +0.00
# HISTORY P14 origin_z = +0.00
# HISTORY P15 rebalance = YES
# HISTORY P16 oversampx = 2
# HISTORY P17 oversampy = 2
# HISTORY P18 pcodemap = NO
# HISTORY P19 pcodethresh = 0.01
# HISTORY P20 corrections = default
# HISTORY P21 keepbits = 7
# HISTORY P22 handedness = left
# HISTORY P23 countscol = INDEF
# HISTORY P24 time = 0
# HISTORY P25 rows = -
# HISTORY P26 copyall = YES
# HISTORY P27 teldef = CALDB
# HISTORY P28 maskwtswgain = 0.03
# HISTORY P29 clobber = YES
# HISTORY P30 append = NO
# HISTORY P31 chatter = 2
# HISTORY P32 history = YES
# HISTORY P33 mode = ql
# HISTORY END PARAMETER list for batfftimage_1.20
# HISTORY

# %% [markdown]
# ## E_MIN   =                  14. / [keV] Lower energy bin edge
#  ## E_MAX   =                194.9 / [keV] Upper energy bin edge
#  ## EXPOSURE=                 178. / exposure of image
#  ## TSTART  =           221640605. / start time of image
# ## TSTOP   =           221640783. / stop time of image
# ## DATE-OBS= '2008-01-10T06:45:04'

# %%
kord=wcs.WCS(hdu[1].header)
kord
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5' / default
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 94.530693279255701  46.357847843278599
# CRPIX : 879.64320238095195  476.64789047619001
# NAXIS : 1760  954

# %%
image=hdu[0].data
image.shape
# Out:
# (954, 1760)

# %%
image
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]], dtype=float32)

# %%
subplot(111,projection=kord) # így mondjuk meg a matplotlib-nek hogy a égi koordinátákat használja

# %%
subplot(111,projection=kord) 
plt.imshow(image, cmap="jet", origin='lower', vmin=-0.001, vmax=0.001)
plt.xlabel('X')
plt.ylabel('Y')
